# %%
import pandas as pd
import numpy as np
import os

# %%
# import data
data_folder = "ML_data"
holidays_events = pd.read_csv(os.path.join(data_folder, "holidays_events.csv"))
oil = pd.read_csv(os.path.join(data_folder, "oil.csv"))
sample_submission = pd.read_csv(os.path.join(data_folder, "sample_submission.csv"))
stores = pd.read_csv(os.path.join(data_folder, "stores.csv")) 
test = pd.read_csv(os.path.join(data_folder, "test.csv"))
train = pd.read_csv(os.path.join(data_folder, "train.csv"))
transactions = pd.read_csv(os.path.join(data_folder, "transactions.csv"))

# %%
train.shape
# Out:
# (3000888, 6)

# %%
# merge
train = train.merge(stores, on="store_nbr", how="left")
train = train.merge(transactions, on=["date", "store_nbr"], how="left")
train = train.merge(oil, on="date", how="left")

# %%
# change holoday df names before merging
# holidays_events = holidays_events.rename(columns=lambda x: f"holiday_{x}" if x != "date" else x)

# %%
train.shape
# Out:
# (3000888, 12)

# %%
train.head(3)
# Out:
#    id        date  store_nbr      family  sales  onpromotion   city  \
# 0   0  2013-01-01          1  AUTOMOTIVE    0.0            0  Quito
# 1   1  2013-01-01          1   BABY CARE    0.0            0  Quito
# 2   2  2013-01-01          1      BEAUTY    0.0            0  Quito
#
#        state type  cluster  transactions  dcoilwtico
# 0  Pichincha    D       13           NaN         NaN
# 1  Pichincha    D       13           NaN         NaN
# 2  Pichincha    D       13           NaN         NaN

# %% [markdown]
# ### Per day per store

# %%
# transaction fill 
train["transactions"] = train["transactions"].fillna(0)

# %%
daily_store_sales = train.groupby(["date", "store_nbr", "city", "state", "type", "cluster","transactions"])["sales"].sum().reset_index()
daily_store_sales
# Out:
#              date  store_nbr           city                           state  \
# 0      2013-01-01          1          Quito                       Pichincha
# 1      2013-01-01          2          Quito                       Pichincha
# 2      2013-01-01          3          Quito                       Pichincha
# 3      2013-01-01          4          Quito                       Pichincha
# 4      2013-01-01          5  Santo Domingo  Santo Domingo de los Tsachilas
# ...           ...        ...            ...                             ...
# 90931  2017-08-15         50         Ambato                      Tungurahua
# 90932  2017-08-15         51      Guayaquil                          Guayas
# 90933  2017-08-15         52          Manta                          Manabi
# 90934  2017-08-15         53          Manta                          Manabi
# 90935  2017-08-15         54      El Carmen                          Manabi
#
#       type  cluster  transactions         sales
# 0        D       13           0.0      0.000000
# 1        D       13           0.0      0.000000
# 2        D        8           0.0      0.000000
# 3        D        9           0.0      0.000000
# 4        D        4           0.0      0.000000
# ...    ...      ...           ...           ...
# 90931    A       14        2804.0  16879.121004
# 90932    A       17        1573.0  20154.559000
# 90933    A       11        2255.0  18600.046000
# 90934    D       13         932.0   8208.189000
# 90935    C        3         802.0  12666.858000
#
# [90936 rows x 8 columns]

# %%
holidays=holidays_events[holidays_events['transferred']=='False']
holidays = holidays[(holidays['locale'] == 'National') | (holidays['locale'] == 'Local')]

# %%
# Add the 'is_national_holiday' column
holidays['is_national_holiday'] = holidays['locale'].apply(lambda x: 1 if x == 'National' else 0)

# Apply the conditional logic for 'locale_name'
holidays['locale_name'] = holidays.apply(
    lambda row: row['locale_name'] if row['is_national_holiday'] == 0 else None, axis=1
)

# Group by 'date' to get the highest value of 'is_national_holiday' (1 if any holiday on that date is national)
holidays_filtered = holidays.groupby('date').agg(
    is_national_holiday=('is_national_holiday', 'max'),
    locale_name=('locale_name', 'first')  # Keep 'locale_name' for reference
).reset_index()

# Select relevant columns and display the result
holiday = holidays_filtered[['date', 'is_national_holiday', 'locale_name']]

# %%
daily_store_sales=pd.merge(daily_store_sales,holiday,on='date',how='left')
daily_store_sales['is_local_holiday']=daily_store_sales['city']==daily_store_sales['locale_name']
daily_store_sales['is_holiday']=daily_store_sales['is_local_holiday'] | daily_store_sales['is_national_holiday']

# %%
daily_store_sales
# Out:
#              date  store_nbr           city                           state  \
# 0      2013-01-01          1          Quito                       Pichincha
# 1      2013-01-01          2          Quito                       Pichincha
# 2      2013-01-01          3          Quito                       Pichincha
# 3      2013-01-01          4          Quito                       Pichincha
# 4      2013-01-01          5  Santo Domingo  Santo Domingo de los Tsachilas
# ...           ...        ...            ...                             ...
# 90931  2017-08-15         50         Ambato                      Tungurahua
# 90932  2017-08-15         51      Guayaquil                          Guayas
# 90933  2017-08-15         52          Manta                          Manabi
# 90934  2017-08-15         53          Manta                          Manabi
# 90935  2017-08-15         54      El Carmen                          Manabi
#
#       type  cluster  transactions         sales is_national_holiday  \
# 0        D       13           0.0      0.000000                 NaN
# 1        D       13           0.0      0.000000                 NaN
# 2        D        8           0.0      0.000000                 NaN
# 3        D        9           0.0      0.000000                 NaN
# 4        D        4           0.0      0.000000                 NaN
# ...    ...      ...           ...           ...                 ...
# 90931    A       14        2804.0  16879.121004                 NaN
# 90932    A       17        1573.0  20154.559000                 NaN
# 90933    A       11        2255.0  18600.046000                 NaN
# 90934    D       13         932.0   8208.189000                 NaN
# 90935    C        3         802.0  12666.858000                 NaN
#
#        locale_name  is_local_holiday  is_holiday
# 0              NaN             False       False
# 1              NaN             False       False
# 2              NaN             False       False
# 3              NaN             False       False
# 4              NaN             False       False
# ...            ...               ...         ...
# 90931          NaN             False       False
# 90932          NaN             False       False
# 90933          NaN             False       False
# 90934          NaN             False       False
# 90935          NaN             False       False
#
# [90936 rows x 12 columns]

# %%
# Drop unnecessary columns related to intermediate holiday flags
columns_to_drop = ["is_national_holiday", "locale_name", "is_local_holiday"]

# Drop the columns
daily_store_sales = daily_store_sales.drop(columns=columns_to_drop, errors='ignore')
daily_store_sales
# Out:
#              date  store_nbr           city                           state  \
# 0      2013-01-01          1          Quito                       Pichincha
# 1      2013-01-01          2          Quito                       Pichincha
# 2      2013-01-01          3          Quito                       Pichincha
# 3      2013-01-01          4          Quito                       Pichincha
# 4      2013-01-01          5  Santo Domingo  Santo Domingo de los Tsachilas
# ...           ...        ...            ...                             ...
# 90931  2017-08-15         50         Ambato                      Tungurahua
# 90932  2017-08-15         51      Guayaquil                          Guayas
# 90933  2017-08-15         52          Manta                          Manabi
# 90934  2017-08-15         53          Manta                          Manabi
# 90935  2017-08-15         54      El Carmen                          Manabi
#
#       type  cluster  transactions         sales  is_holiday
# 0        D       13           0.0      0.000000       False
# 1        D       13           0.0      0.000000       False
# 2        D        8           0.0      0.000000       False
# 3        D        9           0.0      0.000000       False
# 4        D        4           0.0      0.000000       False
# ...    ...      ...           ...           ...         ...
# 90931    A       14        2804.0  16879.121004       False
# 90932    A       17        1573.0  20154.559000       False
# 90933    A       11        2255.0  18600.046000       False
# 90934    D       13         932.0   8208.189000       False
# 90935    C        3         802.0  12666.858000       False
#
# [90936 rows x 9 columns]

# %%
# Export the cleaned dataset to a CSV file
output_file_path = "sales_per_day_per_store.csv"
daily_store_sales.to_csv(output_file_path, index=False)
